# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel('Only.xls',skiprows = [0])

# %%
df.head()
# Out:
#    Sr. No Room No.   Col  Row Total Strength Description of Room   Remarks
# 0       1   25-101  12.0  5.0             60           Class room      NaN
# 1       2  25-101A  12.0  5.0             60           Class room      NaN
# 2       3   25-102   9.0  7.0             63           Class room      NaN
# 3       4  25-102A  12.0  5.0             60           Class room      NaN
# 4       5   25-103   9.0  7.0             63           Class room      NaN

# %%
df['Room No.'] = df['Room No.'].str.replace('-',' ')

# %%
df.head()
# Out:
#    Sr. No Room No.   Col  Row Total Strength Description of Room   Remarks
# 0       1   25 101  12.0  5.0             60           Class room      NaN
# 1       2  25 101A  12.0  5.0             60           Class room      NaN
# 2       3   25 102   9.0  7.0             63           Class room      NaN
# 3       4  25 102A  12.0  5.0             60           Class room      NaN
# 4       5   25 103   9.0  7.0             63           Class room      NaN

# %%
#  x['1_Month_bf'] = x['1Month Price'].split(',', expand = True)

# %%
df[['Block','Room No.']] = df['Room No.'].str.split(expand=True)

# %%
df.head()
# Out:
#    Sr. No Room No.   Col  Row Total Strength Description of Room   Remarks  \
# 0       1      101  12.0  5.0             60           Class room      NaN
# 1       2     101A  12.0  5.0             60           Class room      NaN
# 2       3      102   9.0  7.0             63           Class room      NaN
# 3       4     102A  12.0  5.0             60           Class room      NaN
# 4       5      103   9.0  7.0             63           Class room      NaN
#
#   Block
# 0    25
# 1    25
# 2    25
# 3    25
# 4    25

# %%
df = df.drop('Remarks',axis = 1)

# %%
df.head()
# Out:
#    Sr. No Room No.   Col  Row Total Strength Description of Room  Block
# 0       1      101  12.0  5.0             60           Class room    25
# 1       2     101A  12.0  5.0             60           Class room    25
# 2       3      102   9.0  7.0             63           Class room    25
# 3       4     102A  12.0  5.0             60           Class room    25
# 4       5      103   9.0  7.0             63           Class room    25

# %%
df = df[['Sr. No','Block', 'Room No.','Col','Row','Total Strength', 'Description of Room ']]

# %%
df.head()
# Out:
#    Sr. No Block Room No.   Col  Row Total Strength Description of Room
# 0       1    25      101  12.0  5.0             60           Class room
# 1       2    25     101A  12.0  5.0             60           Class room
# 2       3    25      102   9.0  7.0             63           Class room
# 3       4    25     102A  12.0  5.0             60           Class room
# 4       5    25      103   9.0  7.0             63           Class room

# %%
df.dtypes
# Out:
# Sr. No                    int64
# Block                    object
# Room No.                 object
# Col                     float64
# Row                     float64
# Total Strength           object
# Description of Room      object
# dtype: object

# %%
# pivot table

# %%
df['Block'] = df['Block'].fillna(0)

# %%
df.head()
# Out:
#    Sr. No Block Room No.   Col  Row Total Strength Description of Room
# 0       1    25      101  12.0  5.0             60           Class room
# 1       2    25     101A  12.0  5.0             60           Class room
# 2       3    25      102   9.0  7.0             63           Class room
# 3       4    25     102A  12.0  5.0             60           Class room
# 4       5    25      103   9.0  7.0             63           Class room

# %%
#df.pivot(index = 'Block', columns = 'Room No.','Col','Row','Total Strength','Description of Room'

# %%
df.pivot(index = "Description of Room",columns = "Room No.")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [121], in <cell line: 1>()
# ----> 1 df.pivot(index = "Description of Room",columns = "Room No.")
#
# File c:\users\dell\appdata\local\programs\python\python38\lib\site-packages\pandas\core\frame.py:7876, in DataFrame.pivot(self, index, columns, values)
#    7871 @Substitution("")
#    7872 @Appender(_shared_docs["pivot"])
#    7873 def pivot(self, index=None, columns=None, values=None) -> DataFrame:
#    7874     from pandas.core.reshape.pivot import pivot
# -> 7876     return pivot(self, index=index, columns=columns, values=values)
#
# File c:\users\dell\appdata\local\programs\python\python38\lib\site-packages\pandas\core\reshape\pivot.py:493, in pivot(data, index, columns, values)
#     490     append = index is None
#     491     # error: Unsupported operand types for + ("List[Any]" and "ExtensionArray")
# ...
